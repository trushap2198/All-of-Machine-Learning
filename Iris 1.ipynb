# %% [markdown]
# # Lets start with iris dataset

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
irisdf=pd.read_csv('iris.csv')

# %%
type(irisdf)
# Out:
# pandas.core.frame.DataFrame

# %%
irisdf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
irisdf.shape
# Out:
# (150, 5)

# %%
labels=irisdf['species']

# %%
labels
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
# 5         setosa
# 6         setosa
# 7         setosa
# 8         setosa
# 9         setosa
# 10        setosa
# 11        setosa
# 12        setosa
# 13        setosa
# 14        setosa
# 15        setosa
# 16        setosa
# 17        setosa
# 18        setosa
# 19        setosa
# 20        setosa
# 21        setosa
# 22        setosa
# 23        setosa
# 24        setosa
# 25        setosa
# 26        setosa
# 27        setosa
# 28        setosa
# 29        setosa
#          ...
# 120    virginica
# 121    virginica
# 122    virginica
# 123    virginica
# 124    virginica
# 125    virginica
# 126    virginica
# 127    virginica
# 128    virginica
# 129    virginica
# 130    virginica
# 131    virginica
# 132    virginica
# 133    virginica
# 134    virginica
# 135    virginica
# 136    virginica
# 137    virginica
# 138    virginica
# 139    virginica
# 140    virginica
# ...

# %%
type(labels)
# Out:
# pandas.core.series.Series

# %%
irisdf.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa

# %%
irisdf['species'].value_counts()
#each species class has 50 counts
#thus balanced datasets
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
irisdf.plot(kind='scatter',x='sepal_length',y='sepal_width',label='iris',title='Iris sepal Scatter')
plt.grid()
#as we did dataframe.plot no separate plt.title,plt.xlabel etc needed
#plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(irisdf,hue='species',size=8)\#hue to give color
.map(plt.scatter,'sepal_length','sepal_width')\#to map the funtion of plt.scatter to two cols
.add_legend();#to add legend of values in species column

# %%
sns.set_style('whitegrid')
fg=sns.FacetGrid(irisdf,hue='species',size=8)#hue to give color
mp=fg.map(plt.scatter,'sepal_length','sepal_width')#to map the funtion of plt.scatter to two cols
final_plot=mp.add_legend();#to add legend of values in species column

# %%
type(fg)
# Out:
# seaborn.axisgrid.FacetGrid

# %%
type(mp)
# Out:
# seaborn.axisgrid.FacetGrid

# %% [markdown]
# we observe large part of the setosa flowers can be separated by linear relations but not so for the other two flowers

# %%
#3d scatter plots:plot.ly
#we can't visualize dimensions for than 3(fun fact!!!)

# %%
sns.set_style('whitegrid')
sns.pairplot(irisdf,hue='species',size=4)
#pair plots try to plot all possible pairs
#as we have 4 cols other than hue(species) we get 4C2=6 plots + 3plots of PDF's of each feature

# %%
# Now what if we had 100 features?

# %%
#we get 100C2 plots!!!! Haa
#Do dimensionality reduction techniques
